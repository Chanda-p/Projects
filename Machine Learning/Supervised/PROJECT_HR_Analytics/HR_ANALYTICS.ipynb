# %%
#import all the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#load the dataset
data = pd.read_csv("/content/people.csv")

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
#explore our dataset(EDA):
data.head()        #returns top 5 records from the dataset
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
data.tail()    #returns last 5 records
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 14994    support  medium
# 14995      sales     low
# ...

# %%
data.shape            #returns the number of rows and columns present in the dataset
# Out:
# (14999, 10)

# %%
data.info()          #returns the entire information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data.describe()      #returns the statistical description of the data in the dataset
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       11991.000000    11991.000000      11991.000000     11991.000000
# mean            0.629658        0.716683          3.802852       200.473522
# std             0.241070        0.168343          1.163238        48.727813
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.480000        0.570000          3.000000       157.000000
# 50%             0.660000        0.720000          4.000000       200.000000
# 75%             0.820000        0.860000          5.000000       243.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       11991.000000  11991.000000  11991.000000           11991.000000
# mean            3.364857      0.154282      0.166041               0.016929
# ...

# %%
# DATA PRE-PROCESSING

# try to find out impurities and remove them

#find null values


data.isnull()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
data.isna()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
data.isna().sum()             #returns the count of null values from every columns
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
#dropna() --------> drops or removes all the records of missing values

# %%
#checking the duplicate records:

data[data.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
#removing the duplicate records:

data = data.drop_duplicates(keep = "first")

# %%
data.shape
# Out:
# (11991, 10)

# %%
14999 - 3008
# Out:
# 11991

# %%
#correlation

data.corr()
# Out:
# <ipython-input-17-e9569706e579>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
# ...

# %%
sns.heatmap(data.corr(),cmap="Greens", annot=True)
# Out:
# <ipython-input-18-454a59b27aa7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),cmap="Greens", annot=True)
# <Axes: >

# %%
sns.heatmap(data.corr(),annot=True,cmap="Blues")
# Out:
# <ipython-input-19-b9e2e5522f1c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,cmap="Blues")
# <Axes: >

# %%
sns.heatmap(data.corr(),annot=True,cmap="rainbow")
# Out:
# <ipython-input-20-6829fc171a51>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,cmap="rainbow")
# <Axes: >

# %%
ftr = ["dept","numberOfProjects","timeSpent.company","workAccident","promotionInLast5years","salary"]

# %%
ftr
# Out:
# ['dept',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years',
#  'salary']

# %%
for i,j in enumerate(ftr):
  print(i,j)
# Out:
# 0 dept
# 1 numberOfProjects
# 2 timeSpent.company
# 3 workAccident
# 4 promotionInLast5years
# 5 salary

# %%
fig = plt.subplots(figsize=(20,25))     #to give a figure size

for p,q in enumerate(ftr):
  plt.subplot(3,2,p+1)
  plt.subplots_adjust(hspace=0.5)
  sns.countplot(x=q,data=data,hue="left")
  plt.xticks(rotation=90)
# Out:
# <ipython-input-24-1ca0ec04e810>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,p+1)

# %%
fig = plt.subplots(figsize=(20,25))  #to give figure size

for p,q in enumerate(ftr):
    plt.subplot(3,2,p+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=q,data=data,hue="left")
    plt.xticks(rotation=45)
# Out:
# <ipython-input-25-db2559a2343b>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,p+1)

# %%
# UNDERSTANDINGS:

# 1) Employees with less number of projects as well as with more number of projects are currently on the notice period.

# 2) years of experience : min(3 years) and max(5 years) #crucial time

# 3) promotion plays a significant role #recognition and accredition system to be introduced or some career growth

# 4) employees getting low and medium salary are currently serving the notice period
# incentive based system can be introduced this will make the employees givwe their best....
